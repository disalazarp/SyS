# %% [markdown]
# <a href="https://colab.research.google.com/github/disalazarp/SyS/blob/main/operaciones_de_senales1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def my_ceropen(x,ymin = -5, ymax = 5): # Función para cero y pendiente
  '''
  Codigo base para simular proceso de cero y pendiente
  Se ingresa arreglo de numpy y los valores min  y max despues de cero y pendiente
  '''
  xmax = max(x) # x.max()
  xmin = min(x) # x.min()
  m = (ymax - ymin)/(xmax - xmin)
  c = ymin - m*xmin
  yv = m*x + c
  return yv

F = 50
t_0 = 1/F
Ti = 0
Tf = 3*t_0
n = (Tf-Ti)*F
tv = np.linspace(Ti, Tf, num = n)
xv = A * np.cos(2*np.pi*tv/T_0) #vector de amplitud
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2622360818.py in <cell line: 0>()
#      19 Tf = 3*t_0
#      20 n = (Tf-Ti)*F
# ---> 21 tv = np.linspace(Ti, Tf, num = n)
#      22 xv = A * np.cos(2*np.pi*tv/T_0) #vector de amplitud
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis, device)
#     125
#     126     """
# --> 127     num = operator.index(num)
#     128     if num < 0:
#     129         raise ValueError(
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# ## Ejercicios de los cuadernos

# %% [markdown]
# ###Cuaderno 1

# %%
# Cuaderno 1: intro numpy

# %% [markdown]
# ###Cuaderno 2

# %%
import sympy as sym #importa la librería sympy
sym.init_printing() #se inicializa para mostrar en pantalla

t, sigma, omega = sym.symbols('t sigma omega', real=True)#definir variables simbólicas
s = sigma + 1j*omega  #sobre carga operador para definir parte imaginaria
x = sym.exp(s*t)#función exponencial simbólica desde sympy

# Use la función  rect(t)  para construir una función  cos(ωt)  con  ω=2 , la cual se enciende en  t= −1/2  y se apaga en  t= +1/2 .

class rect(sym.Function): #clase/objeto tipo sympy

    @classmethod #decorador objeto
    def eval(cls, arg):
        return sym.Heaviside(arg + sym.S.Half) - sym.Heaviside(arg - sym.S.Half)
x = sym.cos(omega*t) * rect(t)
sym.plot(x.subs(omega,2), (t, -1, 1), ylim=[-0.2, 1.2], ylabel=r'rect$(t)$');

# %%
# Generar rectificador de onda completa usando la función sgn(t)

y = sym.symbols('y', real=True)
sgn_enY = sym.sign(y)
rect = sym.sin(omega*t) * sgn_enY
sym.plot(rect.subs(omega,1), (t, -1, 1), ylim=[-0.2, 1.2], ylabel=r'rect$(t)$');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-442617323.py in <cell line: 0>()
#       4 sgn_enY = sym.sign(y)
#       5 rect = sym.sin(omega*t) * sgn_enY
# ----> 6 sym.plot(rect.subs(omega,1), (t, -1, 1), ylim=[-0.2, 1.2], ylabel=r'rect$(t)$');
#
# /usr/local/lib/python3.12/dist-packages/sympy/plotting/plot.py in plot(show, *args, **kwargs)
#     396     """
#     397     args = _plot_sympify(args)
# --> 398     plot_expr = _check_arguments(args, 1, 1, **kwargs)
#     399     params = kwargs.get("params", None)
#     400     free = set()
#
# /usr/local/lib/python3.12/dist-packages/sympy/plotting/utils.py in _check_arguments(args, nexpr, npar, **kwargs)
#     264         exprs, ranges, label, rendering_kw = _unpack_args(*args)
#     265         free_symbols = set().union(*[e.free_symbols for e in exprs])
# ...

# %%
# Cuaderno 3: operaciones señales continuas
