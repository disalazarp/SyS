# %% [markdown]
# <a href="https://colab.research.google.com/github/disalazarp/SyS/blob/main/ejercicioDiscretizarCuantizar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

def my_ceropen(x,ymin = -5, ymax = 5): # Función para cero y pendiente
  '''
  Codigo base para simular proceso de cero y pendiente
  Se ingresa arreglo de numpy y los valores min  y max despues de cero y pendiente
  '''
  xmax = max(x) # x.max()
  xmin = min(x) # x.min()
  m = (ymax - ymin)/(xmax - xmin)
  c = ymin - m*xmin
  yv = m*x + c
  return yv

F = 50
t_0 = 1/F
Ti = 0
Tf = 3*t_0
n = (Tf-Ti)*F
tv = np.linspace(Ti, Tf, num = n)
xv = A * np.cos(2*np.pi*tv/T_0) #vector de amplitud
